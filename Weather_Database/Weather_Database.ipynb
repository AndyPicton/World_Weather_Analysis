# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import requests
from citipy import citipy
from config2 import weather_api_key
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_current})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | clyde river
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | ponta do sol
# Processing Record 4 of Set 1 | belaya gora
# Processing Record 5 of Set 1 | bandarbeyla
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | bubaque
# Processing Record 8 of Set 1 | provideniya
# Processing Record 9 of Set 1 | carnarvon
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | okha
# Processing Record 12 of Set 1 | saint-philippe
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | tiksi
# Processing Record 17 of Set 1 | lasa
# Processing Record 18 of Set 1 | burica
# City not found. Skipping...
# Processing Record 19 of Set 1 | tevriz
# Processing Record 20 of Set 1 | jian
# Processing Record 21 of Set 1 | saldanha
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | airai
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | butaritari
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | saskylakh
# Processing Record 29 of Set 1 | san patricio
# Processing Record 30 of Set 1 | valdivia
# Processing Record 31 of Set 1 | guerrero negro
# Processing Record 32 of Set 1 | san cristobal
# Processing Record 33 of Set 1 | guangshui
# Processing Record 34 of Set 1 | kamaishi
# Processing Record 35 of Set 1 | saint george
# Processing Record 36 of Set 1 | khatanga
# Processing Record 37 of Set 1 | tuatapere
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | mallama
# City not found. Skipping...
# Processing Record 45 of Set 1 | brandon
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | fare
# Processing Record 48 of Set 1 | flinders
# Processing Record 49 of Set 1 | tuktoyaktuk
# Processing Record 50 of Set 1 | pangnirtung
# Processing Record 1 of Set 2 | finnsnes
# Processing Record 2 of Set 2 | tonj
# Processing Record 3 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 4 of Set 2 | faanui
# Processing Record 5 of Set 2 | katsuura
# Processing Record 6 of Set 2 | zeya
# Processing Record 7 of Set 2 | sikonge
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | new norfolk
# Processing Record 10 of Set 2 | kwinana
# Processing Record 11 of Set 2 | mar del plata
# Processing Record 12 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 13 of Set 2 | dudinka
# Processing Record 14 of Set 2 | fram
# Processing Record 15 of Set 2 | gravdal
# Processing Record 16 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 18 of Set 2 | kristiinankaupunki
# Processing Record 19 of Set 2 | izhma
# Processing Record 20 of Set 2 | mumbwa
# Processing Record 21 of Set 2 | norman wells
# Processing Record 22 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 2 | kholmogory
# Processing Record 24 of Set 2 | bilibino
# Processing Record 25 of Set 2 | westport
# Processing Record 26 of Set 2 | san quintin
# Processing Record 27 of Set 2 | sur
# Processing Record 28 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 2 | grand-santi
# Processing Record 30 of Set 2 | maxixe
# Processing Record 31 of Set 2 | magistralnyy
# Processing Record 32 of Set 2 | chuy
# Processing Record 33 of Set 2 | sebring
# Processing Record 34 of Set 2 | formoso do araguaia
# City not found. Skipping...
# Processing Record 35 of Set 2 | tripoli
# Processing Record 36 of Set 2 | hokitika
# Processing Record 37 of Set 2 | hithadhoo
# Processing Record 38 of Set 2 | husavik
# Processing Record 39 of Set 2 | san isidro
# Processing Record 40 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 2 | arraial do cabo
# Processing Record 42 of Set 2 | apatou
# Processing Record 43 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 44 of Set 2 | bereda
# Processing Record 45 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 2 | thompson
# Processing Record 47 of Set 2 | bengkulu
# Processing Record 48 of Set 2 | qaanaaq
# Processing Record 49 of Set 2 | dikson
# Processing Record 50 of Set 2 | torbay
# Processing Record 1 of Set 3 | biak
# Processing Record 2 of Set 3 | ribeira grande
# Processing Record 3 of Set 3 | pali
# Processing Record 4 of Set 3 | port elizabeth
# Processing Record 5 of Set 3 | mildura
# Processing Record 6 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 3 | georgetown
# Processing Record 8 of Set 3 | chokurdakh
# Processing Record 9 of Set 3 | mount gambier
# Processing Record 10 of Set 3 | yar-sale
# Processing Record 11 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 3 | bethel
# Processing Record 13 of Set 3 | lompoc
# Processing Record 14 of Set 3 | maracacume
# Processing Record 15 of Set 3 | krasnoselkup
# Processing Record 16 of Set 3 | amapa
# Processing Record 17 of Set 3 | zhitikara
# City not found. Skipping...
# Processing Record 18 of Set 3 | aleksandrov gay
# Processing Record 19 of Set 3 | galveston
# Processing Record 20 of Set 3 | waipawa
# Processing Record 21 of Set 3 | kefamenanu
# Processing Record 22 of Set 3 | kaitangata
# Processing Record 23 of Set 3 | rossland
# Processing Record 24 of Set 3 | tilichiki
# Processing Record 25 of Set 3 | ayios kirikos
# City not found. Skipping...
# Processing Record 26 of Set 3 | mayo
# Processing Record 27 of Set 3 | cape coast
# Processing Record 28 of Set 3 | kruisfontein
# Processing Record 29 of Set 3 | rio grande
# Processing Record 30 of Set 3 | namibe
# Processing Record 31 of Set 3 | albany
# Processing Record 32 of Set 3 | luganville
# Processing Record 33 of Set 3 | gorom-gorom
# Processing Record 34 of Set 3 | muros
# Processing Record 35 of Set 3 | longyearbyen
# Processing Record 36 of Set 3 | beyneu
# Processing Record 37 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 3 | benguela
# Processing Record 39 of Set 3 | busselton
# Processing Record 40 of Set 3 | basoko
# Processing Record 41 of Set 3 | elko
# Processing Record 42 of Set 3 | kieta
# Processing Record 43 of Set 3 | sao filipe
# Processing Record 44 of Set 3 | srednekolymsk
# Processing Record 45 of Set 3 | vostok
# Processing Record 46 of Set 3 | pisco
# Processing Record 47 of Set 3 | tabialan
# City not found. Skipping...
# Processing Record 48 of Set 3 | sechura
# Processing Record 49 of Set 3 | mineiros
# Processing Record 50 of Set 3 | jadu
# Processing Record 1 of Set 4 | bahjoi
# Processing Record 2 of Set 4 | geraldton
# Processing Record 3 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 4 of Set 4 | severo-kurilsk
# Processing Record 5 of Set 4 | santa barbara
# Processing Record 6 of Set 4 | cidreira
# Processing Record 7 of Set 4 | pouembout
# Processing Record 8 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 4 | hasaki
# Processing Record 10 of Set 4 | agadez
# Processing Record 11 of Set 4 | sabha
# Processing Record 12 of Set 4 | bathsheba
# Processing Record 13 of Set 4 | cape town
# Processing Record 14 of Set 4 | gamba
# Processing Record 15 of Set 4 | buala
# Processing Record 16 of Set 4 | rawson
# Processing Record 17 of Set 4 | ndele
# Processing Record 18 of Set 4 | zavallya
# Processing Record 19 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 4 | madawaska
# Processing Record 21 of Set 4 | el tigre
# Processing Record 22 of Set 4 | cabo san lucas
# Processing Record 23 of Set 4 | talcahuano
# Processing Record 24 of Set 4 | namatanai
# Processing Record 25 of Set 4 | miri
# Processing Record 26 of Set 4 | khormuj
# City not found. Skipping...
# Processing Record 27 of Set 4 | kvarkeno
# Processing Record 28 of Set 4 | eirunepe
# Processing Record 29 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 4 | atocha
# Processing Record 31 of Set 4 | baykit
# Processing Record 32 of Set 4 | north bend
# Processing Record 33 of Set 4 | coquimbo
# Processing Record 34 of Set 4 | beloha
# Processing Record 35 of Set 4 | ketchikan
# Processing Record 36 of Set 4 | esperance
# Processing Record 37 of Set 4 | port hardy
# Processing Record 38 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 4 | calvinia
# Processing Record 40 of Set 4 | vila velha
# Processing Record 41 of Set 4 | egvekinot
# Processing Record 42 of Set 4 | chiredzi
# Processing Record 43 of Set 4 | igarka
# Processing Record 44 of Set 4 | baiyin
# Processing Record 45 of Set 4 | west lafayette
# Processing Record 46 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 47 of Set 4 | hay river
# Processing Record 48 of Set 4 | mbaiki
# Processing Record 49 of Set 4 | aguimes
# Processing Record 50 of Set 4 | lavrentiya
# Processing Record 1 of Set 5 | palmer
# Processing Record 2 of Set 5 | tuding
# Processing Record 3 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 5 | nakamura
# Processing Record 5 of Set 5 | yerbogachen
# Processing Record 6 of Set 5 | hamilton
# Processing Record 7 of Set 5 | bonthe
# Processing Record 8 of Set 5 | marovoay
# Processing Record 9 of Set 5 | naze
# Processing Record 10 of Set 5 | rajanpur
# Processing Record 11 of Set 5 | cianorte
# Processing Record 12 of Set 5 | vestmannaeyjar
# Processing Record 13 of Set 5 | orumiyeh
# Processing Record 14 of Set 5 | ugoofaaru
# Processing Record 15 of Set 5 | jumla
# Processing Record 16 of Set 5 | codrington
# Processing Record 17 of Set 5 | tevaitoa
# Processing Record 18 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 5 | khandyga
# Processing Record 20 of Set 5 | urdzhar
# City not found. Skipping...
# Processing Record 21 of Set 5 | rocha
# Processing Record 22 of Set 5 | ostrovnoy
# Processing Record 23 of Set 5 | blonduos
# City not found. Skipping...
# Processing Record 24 of Set 5 | paita
# Processing Record 25 of Set 5 | noumea
# Processing Record 26 of Set 5 | dingle
# Processing Record 27 of Set 5 | iqaluit
# Processing Record 28 of Set 5 | yamada
# Processing Record 29 of Set 5 | ruteng
# Processing Record 30 of Set 5 | yambio
# Processing Record 31 of Set 5 | karpogory
# Processing Record 32 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 33 of Set 5 | bardiyah
# Processing Record 34 of Set 5 | alofi
# Processing Record 35 of Set 5 | dire
# Processing Record 36 of Set 5 | la asuncion
# Processing Record 37 of Set 5 | victoria
# Processing Record 38 of Set 5 | ondo
# Processing Record 39 of Set 5 | nyurba
# Processing Record 40 of Set 5 | kerema
# Processing Record 41 of Set 5 | nanakuli
# Processing Record 42 of Set 5 | north myrtle beach
# Processing Record 43 of Set 5 | emerald
# Processing Record 44 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 5 | mokshan
# Processing Record 47 of Set 5 | isangel
# Processing Record 48 of Set 5 | pevek
# Processing Record 49 of Set 5 | kodiak
# Processing Record 50 of Set 5 | sinnamary
# Processing Record 1 of Set 6 | ondjiva
# Processing Record 2 of Set 6 | luorong
# Processing Record 3 of Set 6 | tagusao
# Processing Record 4 of Set 6 | east london
# Processing Record 5 of Set 6 | san andres
# Processing Record 6 of Set 6 | qui nhon
# Processing Record 7 of Set 6 | chara
# Processing Record 8 of Set 6 | hualmay
# Processing Record 9 of Set 6 | te anau
# Processing Record 10 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 6 | hambantota
# Processing Record 12 of Set 6 | homer
# Processing Record 13 of Set 6 | talnakh
# Processing Record 14 of Set 6 | bontang
# Processing Record 15 of Set 6 | caraz
# Processing Record 16 of Set 6 | sao joao da barra
# Processing Record 17 of Set 6 | padang
# Processing Record 18 of Set 6 | dujuma
# City not found. Skipping...
# Processing Record 19 of Set 6 | kastamonu
# Processing Record 20 of Set 6 | lorengau
# Processing Record 21 of Set 6 | maceio
# Processing Record 22 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 6 | vardo
# Processing Record 24 of Set 6 | souillac
# Processing Record 25 of Set 6 | carlisle
# Processing Record 26 of Set 6 | mahebourg
# Processing Record 27 of Set 6 | wewak
# Processing Record 28 of Set 6 | chapais
# Processing Record 29 of Set 6 | bethanien
# Processing Record 30 of Set 6 | faya
# Processing Record 31 of Set 6 | toora-khem
# Processing Record 32 of Set 6 | kavaratti
# Processing Record 33 of Set 6 | plerin
# Processing Record 34 of Set 6 | cayenne
# Processing Record 35 of Set 6 | alzamay
# Processing Record 36 of Set 6 | atambua
# Processing Record 37 of Set 6 | brownsville
# Processing Record 38 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 39 of Set 6 | touros
# Processing Record 40 of Set 6 | eenhana
# Processing Record 41 of Set 6 | holetown
# Processing Record 42 of Set 6 | nuuk
# Processing Record 43 of Set 6 | itu
# Processing Record 44 of Set 6 | hohhot
# Processing Record 45 of Set 6 | verkhnyaya toyma
# Processing Record 46 of Set 6 | guozhen
# Processing Record 47 of Set 6 | doha
# Processing Record 48 of Set 6 | broome
# Processing Record 49 of Set 6 | ilulissat
# Processing Record 50 of Set 6 | tazovskiy
# Processing Record 1 of Set 7 | plettenberg bay
# Processing Record 2 of Set 7 | mogzon
# Processing Record 3 of Set 7 | dickinson
# Processing Record 4 of Set 7 | leningradskiy
# Processing Record 5 of Set 7 | lincoln
# Processing Record 6 of Set 7 | fairview
# Processing Record 7 of Set 7 | mao
# Processing Record 8 of Set 7 | manokwari
# Processing Record 9 of Set 7 | klaksvik
# Processing Record 10 of Set 7 | yagodnoye
# Processing Record 11 of Set 7 | atuona
# Processing Record 12 of Set 7 | kahului
# Processing Record 13 of Set 7 | senno
# Processing Record 14 of Set 7 | novyy rogachik
# Processing Record 15 of Set 7 | mesaria
# Processing Record 16 of Set 7 | san pedro
# Processing Record 17 of Set 7 | gazli
# Processing Record 18 of Set 7 | fortuna
# Processing Record 19 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 20 of Set 7 | oga
# Processing Record 21 of Set 7 | rawah
# Processing Record 22 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 7 | fairbanks
# Processing Record 24 of Set 7 | meulaboh
# Processing Record 25 of Set 7 | cherskiy
# Processing Record 26 of Set 7 | amga
# Processing Record 27 of Set 7 | nogliki
# Processing Record 28 of Set 7 | vanimo
# Processing Record 29 of Set 7 | tasiilaq
# Processing Record 30 of Set 7 | chipinge
# Processing Record 31 of Set 7 | puerto colombia
# Processing Record 32 of Set 7 | gisborne
# Processing Record 33 of Set 7 | bull savanna
# Processing Record 34 of Set 7 | tucuman
# Processing Record 35 of Set 7 | jerome
# Processing Record 36 of Set 7 | paracuru
# Processing Record 37 of Set 7 | corrente
# Processing Record 38 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 7 | tierranueva
# Processing Record 40 of Set 7 | nichinan
# Processing Record 41 of Set 7 | thaton
# Processing Record 42 of Set 7 | camana
# Processing Record 43 of Set 7 | muisne
# Processing Record 44 of Set 7 | voh
# Processing Record 45 of Set 7 | chicama
# Processing Record 46 of Set 7 | upernavik
# Processing Record 47 of Set 7 | veraval
# Processing Record 48 of Set 7 | novikovo
# Processing Record 49 of Set 7 | comodoro rivadavia
# Processing Record 50 of Set 7 | mount darwin
# Processing Record 1 of Set 8 | castro
# Processing Record 2 of Set 8 | ahipara
# Processing Record 3 of Set 8 | urengoy
# Processing Record 4 of Set 8 | kiama
# Processing Record 5 of Set 8 | pacific grove
# Processing Record 6 of Set 8 | seymchan
# Processing Record 7 of Set 8 | luderitz
# Processing Record 8 of Set 8 | lagos
# Processing Record 9 of Set 8 | margate
# Processing Record 10 of Set 8 | saint-pierre
# Processing Record 11 of Set 8 | cedar city
# Processing Record 12 of Set 8 | sabancuy
# Processing Record 13 of Set 8 | timmins
# Processing Record 14 of Set 8 | roald
# Processing Record 15 of Set 8 | ferkessedougou
# Processing Record 16 of Set 8 | marsh harbour
# Processing Record 17 of Set 8 | sorland
# Processing Record 18 of Set 8 | secunda
# Processing Record 19 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 20 of Set 8 | kinablangan
# Processing Record 21 of Set 8 | grindavik
# Processing Record 22 of Set 8 | kavieng
# Processing Record 23 of Set 8 | severo-yeniseyskiy
# Processing Record 24 of Set 8 | kloulklubed
# Processing Record 25 of Set 8 | samfya
# Processing Record 26 of Set 8 | shirokiy
# Processing Record 27 of Set 8 | lakes entrance
# Processing Record 28 of Set 8 | anadyr
# Processing Record 29 of Set 8 | malatya
# Processing Record 30 of Set 8 | kostino
# Processing Record 31 of Set 8 | ixtapa
# Processing Record 32 of Set 8 | san ramon
# Processing Record 33 of Set 8 | mehamn
# Processing Record 34 of Set 8 | itanhaem
# Processing Record 35 of Set 8 | hutchinson
# Processing Record 36 of Set 8 | port macquarie
# Processing Record 37 of Set 8 | kemijarvi
# Processing Record 38 of Set 8 | yulara
# Processing Record 39 of Set 8 | mwene-ditu
# Processing Record 40 of Set 8 | nurobod
# Processing Record 41 of Set 8 | deputatskiy
# Processing Record 42 of Set 8 | eden
# Processing Record 43 of Set 8 | kristianstad
# Processing Record 44 of Set 8 | dijkot
# Processing Record 45 of Set 8 | keti bandar
# Processing Record 46 of Set 8 | bambous virieux
# Processing Record 47 of Set 8 | necochea
# Processing Record 48 of Set 8 | at-bashi
# Processing Record 49 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 8 | linguere
# Processing Record 1 of Set 9 | vao
# Processing Record 2 of Set 9 | sitka
# Processing Record 3 of Set 9 | linxia
# Processing Record 4 of Set 9 | dvinskoy
# Processing Record 5 of Set 9 | birin
# Processing Record 6 of Set 9 | aklavik
# Processing Record 7 of Set 9 | mangrol
# Processing Record 8 of Set 9 | amuntai
# Processing Record 9 of Set 9 | college
# Processing Record 10 of Set 9 | maykain
# City not found. Skipping...
# Processing Record 11 of Set 9 | priiskovyy
# Processing Record 12 of Set 9 | port-gentil
# Processing Record 13 of Set 9 | koumac
# Processing Record 14 of Set 9 | karratha
# Processing Record 15 of Set 9 | zaysan
# Processing Record 16 of Set 9 | canayan
# Processing Record 17 of Set 9 | avera
# Processing Record 18 of Set 9 | antalaha
# Processing Record 19 of Set 9 | san gabriel
# Processing Record 20 of Set 9 | rengasdengklok
# Processing Record 21 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 9 | kamloops
# Processing Record 23 of Set 9 | antsohihy
# Processing Record 24 of Set 9 | tromso
# Processing Record 25 of Set 9 | caravelas
# Processing Record 26 of Set 9 | paamiut
# Processing Record 27 of Set 9 | qasigiannguit
# Processing Record 28 of Set 9 | neryungri
# Processing Record 29 of Set 9 | praya
# Processing Record 30 of Set 9 | jaisalmer
# Processing Record 31 of Set 9 | puerto narino
# Processing Record 32 of Set 9 | aksu
# Processing Record 33 of Set 9 | carthage
# Processing Record 34 of Set 9 | corpus christi
# Processing Record 35 of Set 9 | outlook
# Processing Record 36 of Set 9 | verkhnevilyuysk
# Processing Record 37 of Set 9 | tura
# Processing Record 38 of Set 9 | bilma
# Processing Record 39 of Set 9 | mumford
# Processing Record 40 of Set 9 | skagen
# Processing Record 41 of Set 9 | victorville
# Processing Record 42 of Set 9 | kismayo
# Processing Record 43 of Set 9 | nanortalik
# Processing Record 44 of Set 9 | dakar
# Processing Record 45 of Set 9 | gidam
# Processing Record 46 of Set 9 | axim
# Processing Record 47 of Set 9 | matara
# Processing Record 48 of Set 9 | conde
# Processing Record 49 of Set 9 | poum
# Processing Record 50 of Set 9 | taybad
# Processing Record 1 of Set 10 | lemesos
# City not found. Skipping...
# Processing Record 2 of Set 10 | korgen
# Processing Record 3 of Set 10 | acarau
# Processing Record 4 of Set 10 | koslan
# Processing Record 5 of Set 10 | hofn
# Processing Record 6 of Set 10 | tarauaca
# Processing Record 7 of Set 10 | taltal
# Processing Record 8 of Set 10 | milingimbi
# City not found. Skipping...
# Processing Record 9 of Set 10 | kanigoro
# Processing Record 10 of Set 10 | nikolskoye
# Processing Record 11 of Set 10 | ulladulla
# Processing Record 12 of Set 10 | kutum
# Processing Record 13 of Set 10 | thanh hoa
# Processing Record 14 of Set 10 | santa catarina de tepehuanes
# Processing Record 15 of Set 10 | sorong
# Processing Record 16 of Set 10 | fort nelson
# Processing Record 17 of Set 10 | brebes
# Processing Record 18 of Set 10 | acevedo
# Processing Record 19 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 20 of Set 10 | montrose
# Processing Record 21 of Set 10 | baie-comeau
# Processing Record 22 of Set 10 | palana
# Processing Record 23 of Set 10 | lerwick
# Processing Record 24 of Set 10 | pochutla
# Processing Record 25 of Set 10 | hvammstangi
# City not found. Skipping...
# Processing Record 26 of Set 10 | novyy urgal
# Processing Record 27 of Set 10 | khani
# Processing Record 28 of Set 10 | puerto escondido
# Processing Record 29 of Set 10 | talavera de la reina
# Processing Record 30 of Set 10 | tautira
# Processing Record 31 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 10 | follonica
# Processing Record 33 of Set 10 | diu
# Processing Record 34 of Set 10 | litovko
# Processing Record 35 of Set 10 | ornskoldsvik
# Processing Record 36 of Set 10 | havre-saint-pierre
# Processing Record 37 of Set 10 | carbondale
# Processing Record 38 of Set 10 | ekhabi
# Processing Record 39 of Set 10 | cedeno
# Processing Record 40 of Set 10 | hovd
# Processing Record 41 of Set 10 | rozhyshche
# Processing Record 42 of Set 10 | mount isa
# Processing Record 43 of Set 10 | yatou
# Processing Record 44 of Set 10 | shubarkuduk
# Processing Record 45 of Set 10 | teguldet
# Processing Record 46 of Set 10 | ibadan
# Processing Record 47 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 48 of Set 10 | tuscaloosa
# Processing Record 49 of Set 10 | tecoanapa
# Processing Record 50 of Set 10 | heyang
# Processing Record 1 of Set 11 | nouadhibou
# Processing Record 2 of Set 11 | san juan
# Processing Record 3 of Set 11 | akniste
# Processing Record 4 of Set 11 | richards bay
# Processing Record 5 of Set 11 | shu
# Processing Record 6 of Set 11 | georgiyevka
# Processing Record 7 of Set 11 | portland
# Processing Record 8 of Set 11 | kimbe
# Processing Record 9 of Set 11 | karaton
# Processing Record 10 of Set 11 | porto empedocle
# Processing Record 11 of Set 11 | stillwater
# Processing Record 12 of Set 11 | boa vista
# Processing Record 13 of Set 11 | jibuti
# Processing Record 14 of Set 11 | bac lieu
# Processing Record 15 of Set 11 | ucluelet
# Processing Record 16 of Set 11 | daxian
# City not found. Skipping...
# Processing Record 17 of Set 11 | laramie
# Processing Record 18 of Set 11 | inhambane
# Processing Record 19 of Set 11 | melita
# Processing Record 20 of Set 11 | san fernando
# Processing Record 21 of Set 11 | boguchany
# Processing Record 22 of Set 11 | upington
# Processing Record 23 of Set 11 | santa helena de goias
# Processing Record 24 of Set 11 | itacoatiara
# Processing Record 25 of Set 11 | dongsheng
# Processing Record 26 of Set 11 | salalah
# Processing Record 27 of Set 11 | harper
# Processing Record 28 of Set 11 | ishigaki
# Processing Record 29 of Set 11 | hobyo
# Processing Record 30 of Set 11 | korla
# Processing Record 31 of Set 11 | leshukonskoye
# Processing Record 32 of Set 11 | kasongo-lunda
# Processing Record 33 of Set 11 | ushtobe
# Processing Record 34 of Set 11 | nisia floresta
# Processing Record 35 of Set 11 | bemidji
# Processing Record 36 of Set 11 | esteio
# Processing Record 37 of Set 11 | haines junction
# Processing Record 38 of Set 11 | lata
# Processing Record 39 of Set 11 | maniitsoq
# Processing Record 40 of Set 11 | cam ranh
# Processing Record 41 of Set 11 | aleksandrovskoye
# Processing Record 42 of Set 11 | plopsoru
# Processing Record 43 of Set 11 | mayumba
# Processing Record 44 of Set 11 | ajdabiya
# Processing Record 45 of Set 11 | along
# Processing Record 46 of Set 11 | vila franca do campo
# Processing Record 47 of Set 11 | half moon bay
# Processing Record 48 of Set 11 | ashtabula
# Processing Record 49 of Set 11 | hami
# Processing Record 50 of Set 11 | tank
# Processing Record 1 of Set 12 | sioux lookout
# Processing Record 2 of Set 12 | san javier
# Processing Record 3 of Set 12 | barma
# Processing Record 4 of Set 12 | vila
# Processing Record 5 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 6 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 12 | abu dhabi
# Processing Record 8 of Set 12 | goundam
# Processing Record 9 of Set 12 | guane
# Processing Record 10 of Set 12 | le havre
# Processing Record 11 of Set 12 | standerton
# Processing Record 12 of Set 12 | soyo
# Processing Record 13 of Set 12 | morehead
# Processing Record 14 of Set 12 | ipixuna
# Processing Record 15 of Set 12 | almaznyy
# Processing Record 16 of Set 12 | gainesville
# Processing Record 17 of Set 12 | champerico
# Processing Record 18 of Set 12 | zolotinka
# City not found. Skipping...
# Processing Record 19 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 20 of Set 12 | moyale
# Processing Record 21 of Set 12 | laguna
# Processing Record 22 of Set 12 | takhli
# Processing Record 23 of Set 12 | mananara
# Processing Record 24 of Set 12 | cheremkhovo
# Processing Record 25 of Set 12 | atagay
# Processing Record 26 of Set 12 | makakilo city
# Processing Record 27 of Set 12 | seoul
# Processing Record 28 of Set 12 | mosquera
# Processing Record 29 of Set 12 | itarema
# Processing Record 30 of Set 12 | bosaso
# Processing Record 31 of Set 12 | ongandjera
# Processing Record 32 of Set 12 | los llanos de aridane
# Processing Record 33 of Set 12 | carutapera
# Processing Record 34 of Set 12 | bayan
# Processing Record 35 of Set 12 | aviles
# Processing Record 36 of Set 12 | huarmey
# Processing Record 37 of Set 12 | kangaatsiaq
# Processing Record 38 of Set 12 | peniche
# Processing Record 39 of Set 12 | mecca
# Processing Record 40 of Set 12 | havelock
# Processing Record 41 of Set 12 | mokolo
# Processing Record 42 of Set 12 | zhigansk
# Processing Record 43 of Set 12 | burns lake
# Processing Record 44 of Set 12 | nhulunbuy
# Processing Record 45 of Set 12 | aginskoye
# Processing Record 46 of Set 12 | thio
# Processing Record 47 of Set 12 | gataivai
# Processing Record 48 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 49 of Set 12 | cukai
# Processing Record 50 of Set 12 | paramonga
# Processing Record 1 of Set 13 | senanga
# Processing Record 2 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 13 | miranorte
# City not found. Skipping...
# Processing Record 4 of Set 13 | beringovskiy
# Processing Record 5 of Set 13 | rehoboth
# Processing Record 6 of Set 13 | charters towers
# Processing Record 7 of Set 13 | waddan
# Processing Record 8 of Set 13 | tornio
# Processing Record 9 of Set 13 | progreso
# Processing Record 10 of Set 13 | lagoa
# Processing Record 11 of Set 13 | manta
# Processing Record 12 of Set 13 | rio gallegos
# Processing Record 13 of Set 13 | fomboni
# Processing Record 14 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 15 of Set 13 | presidente epitacio
# Processing Record 16 of Set 13 | sangar
# Processing Record 17 of Set 13 | kirando
# Processing Record 18 of Set 13 | tarsus
# Processing Record 19 of Set 13 | waingapu
# Processing Record 20 of Set 13 | chalus
# Processing Record 21 of Set 13 | takapau
# Processing Record 22 of Set 13 | geresk
# City not found. Skipping...
# Processing Record 23 of Set 13 | korem
# Processing Record 24 of Set 13 | nantucket
# Processing Record 25 of Set 13 | prince rupert
# Processing Record 26 of Set 13 | saint-francois
# Processing Record 27 of Set 13 | kuytun
# Processing Record 28 of Set 13 | ronda
# Processing Record 29 of Set 13 | pitimbu
# Processing Record 30 of Set 13 | moindou
# Processing Record 31 of Set 13 | tungi
# Processing Record 32 of Set 13 | kembe
# Processing Record 33 of Set 13 | udachnyy
# Processing Record 34 of Set 13 | jiazi
# Processing Record 35 of Set 13 | puerto gaitan
# Processing Record 36 of Set 13 | barentu
# Processing Record 37 of Set 13 | aykhal
# Processing Record 38 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 13 | chirongui
# Processing Record 40 of Set 13 | huilong
# Processing Record 41 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 13 | yinchuan
# Processing Record 43 of Set 13 | zhezkazgan
# Processing Record 44 of Set 13 | potsdam
# Processing Record 45 of Set 13 | edson
# Processing Record 46 of Set 13 | xining
# Processing Record 47 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 13 | pyinmana
# Processing Record 49 of Set 13 | mantua
# Processing Record 50 of Set 13 | solnechnyy
# Processing Record 1 of Set 14 | zakamensk
# Processing Record 2 of Set 14 | christchurch
# Processing Record 3 of Set 14 | ancud
# Processing Record 4 of Set 14 | tiznit
# Processing Record 5 of Set 14 | iralaya
# Processing Record 6 of Set 14 | orlik
# Processing Record 7 of Set 14 | olean
# Processing Record 8 of Set 14 | rovaniemi
# Processing Record 9 of Set 14 | kyren
# Processing Record 10 of Set 14 | lanzhou
# Processing Record 11 of Set 14 | sonamura
# Processing Record 12 of Set 14 | paris
# Processing Record 13 of Set 14 | lago da pedra
# Processing Record 14 of Set 14 | gemena
# Processing Record 15 of Set 14 | balgazyn
# Processing Record 16 of Set 14 | kulhudhuffushi
# Processing Record 17 of Set 14 | weligama
# Processing Record 18 of Set 14 | praxedis guerrero
# Processing Record 19 of Set 14 | saint anthony
# Processing Record 20 of Set 14 | sharanga
# Processing Record 21 of Set 14 | northallerton
# Processing Record 22 of Set 14 | dunedin
# Processing Record 23 of Set 14 | tyup
# Processing Record 24 of Set 14 | sovetskiy
# Processing Record 25 of Set 14 | marawi
# Processing Record 26 of Set 14 | inirida
# Processing Record 27 of Set 14 | nipawin
# Processing Record 28 of Set 14 | narsaq
# Processing Record 29 of Set 14 | olafsvik
# Processing Record 30 of Set 14 | coffs harbour
# Processing Record 31 of Set 14 | fukue
# Processing Record 32 of Set 14 | evensk
# Processing Record 33 of Set 14 | novyye burasy
# Processing Record 34 of Set 14 | xacmaz
# Processing Record 35 of Set 14 | richmond
# Processing Record 36 of Set 14 | prokuplje
# Processing Record 37 of Set 14 | carbonia
# Processing Record 38 of Set 14 | myitkyina
# Processing Record 39 of Set 14 | praia
# Processing Record 40 of Set 14 | vanavara
# Processing Record 41 of Set 14 | fallon
# Processing Record 42 of Set 14 | san carlos de bariloche
# Processing Record 43 of Set 14 | puri
# Processing Record 44 of Set 14 | gizo
# Processing Record 45 of Set 14 | dotnuva
# Processing Record 46 of Set 14 | hervey bay
# Processing Record 47 of Set 14 | zyryanka
# Processing Record 48 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 49 of Set 14 | ayagoz
# Processing Record 50 of Set 14 | mzimba
# Processing Record 1 of Set 15 | dryden
# Processing Record 2 of Set 15 | ambon
# Processing Record 3 of Set 15 | poso
# Processing Record 4 of Set 15 | moron
# Processing Record 5 of Set 15 | santiago
# Processing Record 6 of Set 15 | blagoyevo
# Processing Record 7 of Set 15 | ambilobe
# Processing Record 8 of Set 15 | adrar
# Processing Record 9 of Set 15 | djambala
# Processing Record 10 of Set 15 | broken hill
# Processing Record 11 of Set 15 | ialibu
# Processing Record 12 of Set 15 | oksfjord
# Processing Record 13 of Set 15 | petrolina
# Processing Record 14 of Set 15 | lazaro cardenas
# Processing Record 15 of Set 15 | luau
# Processing Record 16 of Set 15 | kamenka
# Processing Record 17 of Set 15 | yashkino
# Processing Record 18 of Set 15 | kapoeta
# Processing Record 19 of Set 15 | trinidad
# Processing Record 20 of Set 15 | summerside
# Processing Record 21 of Set 15 | anori
# Processing Record 22 of Set 15 | galich
# Processing Record 23 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 24 of Set 15 | pathein
# Processing Record 25 of Set 15 | yabrud
# Processing Record 26 of Set 15 | norway
# Processing Record 27 of Set 15 | nevsehir
# Processing Record 28 of Set 15 | eureka
# Processing Record 29 of Set 15 | phenix city
# Processing Record 30 of Set 15 | cururupu
# Processing Record 31 of Set 15 | coihaique
# Processing Record 32 of Set 15 | linjiang
# Processing Record 33 of Set 15 | ulkan
# Processing Record 34 of Set 15 | buta
# Processing Record 35 of Set 15 | kushmurun
# Processing Record 36 of Set 15 | pundaguitan
# Processing Record 37 of Set 15 | palatka
# Processing Record 38 of Set 15 | bolshaya murta
# City not found. Skipping...
# Processing Record 39 of Set 15 | kaili
# Processing Record 40 of Set 15 | kalmar
# Processing Record 41 of Set 15 | langham
# Processing Record 42 of Set 15 | morondava
# Processing Record 43 of Set 15 | purnia
# Processing Record 44 of Set 15 | bhaderwah
# Processing Record 45 of Set 15 | saint-georges
# Processing Record 46 of Set 15 | guiratinga
# Processing Record 47 of Set 15 | omboue
# Processing Record 48 of Set 15 | uchaly
# Processing Record 49 of Set 15 | wahpeton
# Processing Record 50 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 16 | oranjestad
# Processing Record 2 of Set 16 | strezhevoy
# Processing Record 3 of Set 16 | solovetskiy
# City not found. Skipping...
# Processing Record 4 of Set 16 | kalispell
# Processing Record 5 of Set 16 | mrirt
# City not found. Skipping...
# Processing Record 6 of Set 16 | nacala
# Processing Record 7 of Set 16 | dubbo
# Processing Record 8 of Set 16 | kaeo
# Processing Record 9 of Set 16 | stepnogorsk
# Processing Record 10 of Set 16 | bayir
# Processing Record 11 of Set 16 | artyk
# City not found. Skipping...
# Processing Record 12 of Set 16 | maridi
# Processing Record 13 of Set 16 | padra
# Processing Record 14 of Set 16 | khash
# Processing Record 15 of Set 16 | taoudenni
# Processing Record 16 of Set 16 | kenai
# Processing Record 17 of Set 16 | mucurapo
# Processing Record 18 of Set 16 | arman
# Processing Record 19 of Set 16 | dorado
# Processing Record 20 of Set 16 | gambela
# Processing Record 21 of Set 16 | minab
# Processing Record 22 of Set 16 | curanilahue
# Processing Record 23 of Set 16 | mazamari
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Clyde River  70.4692  -68.5914     -1.97        84           0
# 1         Bluff -46.6000  168.3333     54.23        52          52
# 2  Ponta Do Sol  32.6667  -17.1000     62.71        81          75
# 3   Belaya Gora  68.5333  146.4167     -3.78        92          83
# 4   Bandarbeyla   9.4942   50.8122     79.09        82           0
# 5  Punta Arenas -53.1500  -70.9167     50.11        62          75
# 6       Bubaque  11.2833  -15.8333     75.47        73         100
# 7   Provideniya  64.3833 -173.3000     23.36        80         100
# 8     Carnarvon -24.8667  113.6333     73.47        94         100
# 9  Puerto Ayora  -0.7393  -90.3518     74.55        99         100
#
#    Wind Speed Country                 Date Current Description
# 0        0.00      CA  2022-04-01 01:10:13           clear sky
# 1        5.75      NZ  2022-04-01 01:10:13       broken clouds
# 2        4.21      PT  2022-04-01 01:10:14       broken clouds
# 3        3.09      RU  2022-04-01 01:10:14       broken clouds
# 4        9.84      SO  2022-04-01 01:10:15           clear sky
# 5       24.16      CL  2022-04-01 01:05:20       broken clouds
# 6       14.70      GW  2022-04-01 01:10:15     overcast clouds
# 7       20.00      RU  2022-04-01 01:10:16          light snow
# 8       17.27      AU  2022-04-01 01:10:16     overcast clouds
# 9        1.95      EC  2022-04-01 01:10:16     overcast clouds

# %%
new_city_data = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
new_city_data
# Out:
# ['City',
#  'Country',
#  'Lat',
#  'Lng',
#  'Max Temp',
#  'Humidity',
#  'Cloudiness',
#  'Wind Speed',
#  'Current Description']

# %%
city_data_df = city_data_df[new_city_data]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Clyde River      CA  70.4692  -68.5914     -1.97        84           0
# 1         Bluff      NZ -46.6000  168.3333     54.23        52          52
# 2  Ponta Do Sol      PT  32.6667  -17.1000     62.71        81          75
# 3   Belaya Gora      RU  68.5333  146.4167     -3.78        92          83
# 4   Bandarbeyla      SO   9.4942   50.8122     79.09        82           0
# 5  Punta Arenas      CL -53.1500  -70.9167     50.11        62          75
# 6       Bubaque      GW  11.2833  -15.8333     75.47        73         100
# 7   Provideniya      RU  64.3833 -173.3000     23.36        80         100
# 8     Carnarvon      AU -24.8667  113.6333     73.47        94         100
# 9  Puerto Ayora      EC  -0.7393  -90.3518     74.55        99         100
#
#    Wind Speed Current Description
# 0        0.00           clear sky
# 1        5.75       broken clouds
# 2        4.21       broken clouds
# 3        3.09       broken clouds
# 4        9.84           clear sky
# 5       24.16       broken clouds
# 6       14.70     overcast clouds
# 7       20.00          light snow
# 8       17.27     overcast clouds
# 9        1.95     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
